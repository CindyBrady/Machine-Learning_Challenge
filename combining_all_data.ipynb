# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("Resources/newmerged12_df.csv")
df2 = pd.read_csv("Resources/newmerged13_df.csv")
df3 = pd.read_csv("Resources/newmerged14_df.csv")
df4 = pd.read_csv("Resources/newmerged15_df.csv")
df5 = pd.read_csv("Resources/newmerged16_df.csv")
df6 = pd.read_csv("Resources/newmerged17_df.csv")
df7 = pd.read_csv("Resources/newmerged18_df.csv")

# %%
frames = [df1, df2, df3, df4, df5, df6, df7]
df = pd.concat(frames)

# %%
df.drop_duplicates()
df
# Out:
#       GAME_SEQUENCE   GAME_ID     TEAM_ID  PTS_QTR1  PTS_QTR2  PTS_QTR3  \
# 0                 1  21200001  1610612764        24        15        23
# 1                 1  21200027  1610612764        12        30        25
# 2                 2  21200054  1610612764        16        26        16
# 3                 1  21200068  1610612764        28        19        25
# 4                 2  21200082  1610612764        22        27        23
# ...             ...       ...         ...       ...       ...       ...
# 2455             11  21801175  1610612757        28        34        24
# 2456             11  21801190  1610612757        29        21        37
# 2457             12  21801206  1610612757        29        31        26
# 2458             11  21801219  1610612757        26        27        20
# 2459             11  21801230  1610612757        30        32        36
#
#       PTS_QTR4  PTS_OT1  PTS_OT2  PTS_OT3  PTS_OT4  PTS  FG_PCT  FT_PCT  \
# ...

# %%
df.to_csv("newmergedfull_df.csv", index=False)
